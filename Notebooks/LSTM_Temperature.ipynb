# %%
import math
from math import sqrt
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from numpy import concatenate
import xarray as xr
import numpy as np
import pandas as pd
import netCDF4 as nc
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
data= pd.read_csv('/content/drive/My Drive/DS_Project/ML_dataframe.csv', encoding= 'latin1')
data
# Out:
#              Date  Precipitation  ...  Air_Pressure       PRW
# 0        1/1/1915       3.372648  ...     83609.850  2.784520
# 1        1/2/1915       5.849281  ...     83221.570  3.970052
# 2        1/3/1915       0.150792  ...     83625.350  3.120856
# 3        1/4/1915       2.477911  ...     83994.516  2.128633
# 4        1/5/1915       0.001109  ...     84009.480  2.024976
# ...           ...            ...  ...           ...       ...
# 36495  12/27/2014       4.814195  ...     83678.870  6.425169
# 36496  12/28/2014       0.004475  ...     83346.450  7.488951
# 36497  12/29/2014       0.000026  ...     83224.750  7.951182
# 36498  12/30/2014       0.032887  ...     83244.586  8.224910
# 36499  12/31/2014       1.155274  ...     83198.850  7.750363
#
# [36500 rows x 6 columns]

# %%
dataset= data[['Temperature', 'Relative_humidity','Precipitation','Air_Pressure','PRW']]

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Multivariate Time Series Forecasting with LSTMs in Keras

# %%
# transform a time series dataset into a supervised learning dataset
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols = list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
	# put it all together
	agg = concat(cols, axis=1)
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg.values

# %%
# load dataset
values = dataset.values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = pd.DataFrame(series_to_supervised(scaled, 1, 1))
print(type(reframed))
# drop columns we don't want to predict
reframed.drop(reframed.columns[[6,7,8,9]], axis=1, inplace=True)
print(reframed.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           0         1         2         3         4         5
# 0  0.401840  0.735837  0.013658  0.551811  0.091526  0.511950
# 1  0.511950  0.803938  0.023688  0.450218  0.135534  0.429381
# 2  0.429381  0.885866  0.000611  0.555866  0.104011  0.489973
# 3  0.489973  0.793712  0.010035  0.652458  0.067179  0.249858
# 4  0.249858  0.701557  0.000004  0.656372  0.063331  0.239559

# %%
values = reframed.values
n_train_data = 27375
train = values[:n_train_data, :]
test = values[n_train_data:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (27375, 1, 5) (27375,) (9124, 1, 5) (9124,)

# %%
...
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 381/381 - 4s - loss: 0.1567 - val_loss: 0.0809 - 4s/epoch - 10ms/step
# Epoch 2/50
# 381/381 - 1s - loss: 0.0651 - val_loss: 0.0561 - 1s/epoch - 3ms/step
# Epoch 3/50
# 381/381 - 1s - loss: 0.0559 - val_loss: 0.0556 - 1s/epoch - 3ms/step
# Epoch 4/50
# 381/381 - 1s - loss: 0.0559 - val_loss: 0.0555 - 1s/epoch - 3ms/step
# Epoch 5/50
# 381/381 - 1s - loss: 0.0559 - val_loss: 0.0555 - 1s/epoch - 3ms/step
# Epoch 6/50
# 381/381 - 1s - loss: 0.0558 - val_loss: 0.0555 - 1s/epoch - 3ms/step
# Epoch 7/50
# 381/381 - 1s - loss: 0.0559 - val_loss: 0.0555 - 1s/epoch - 3ms/step
# Epoch 8/50
# 381/381 - 1s - loss: 0.0559 - val_loss: 0.0555 - 1s/epoch - 3ms/step
# Epoch 9/50
# 381/381 - 1s - loss: 0.0558 - val_loss: 0.0554 - 1s/epoch - 3ms/step
# Epoch 10/50
# 381/381 - 1s - loss: 0.0558 - val_loss: 0.0555 - 1s/epoch - 3ms/step
# Epoch 11/50
# 381/381 - 1s - loss: 0.0558 - val_loss: 0.0554 - 1s/epoch - 3ms/step
# Epoch 12/50
# 381/381 - 1s - loss: 0.0558 - val_loss: 0.0554 - 998ms/epoch - 3ms/step
# Epoch 13/50
# 381/381 - 1s - loss: 0.0558 - val_loss: 0.0553 - 1s/epoch - 3ms/step
# Epoch 14/50
# 381/381 - 1s - loss: 0.0557 - val_loss: 0.0553 - 1s/epoch - 3ms/step
# Epoch 15/50
# 381/381 - 1s - loss: 0.0557 - val_loss: 0.0552 - 1s/epoch - 3ms/step
# Epoch 16/50
# 381/381 - 1s - loss: 0.0556 - val_loss: 0.0551 - 1s/epoch - 3ms/step
# Epoch 17/50
# 381/381 - 1s - loss: 0.0556 - val_loss: 0.0552 - 1s/epoch - 3ms/step
# Epoch 18/50
# 381/381 - 1s - loss: 0.0555 - val_loss: 0.0551 - 1s/epoch - 3ms/step
# Epoch 19/50
# 381/381 - 1s - loss: 0.0555 - val_loss: 0.0551 - 1s/epoch - 3ms/step
# Epoch 20/50
# 381/381 - 1s - loss: 0.0554 - val_loss: 0.0550 - 1s/epoch - 3ms/step
# Epoch 21/50
# 381/381 - 1s - loss: 0.0554 - val_loss: 0.0550 - 1s/epoch - 3ms/step
# Epoch 22/50
# 381/381 - 1s - loss: 0.0553 - val_loss: 0.0549 - 1s/epoch - 3ms/step
# Epoch 23/50
# 381/381 - 1s - loss: 0.0553 - val_loss: 0.0548 - 1s/epoch - 3ms/step
# Epoch 24/50
# 381/381 - 1s - loss: 0.0552 - val_loss: 0.0547 - 1s/epoch - 3ms/step
# Epoch 25/50
# 381/381 - 1s - loss: 0.0551 - val_loss: 0.0546 - 1s/epoch - 3ms/step
# Epoch 26/50
# 381/381 - 1s - loss: 0.0551 - val_loss: 0.0545 - 1s/epoch - 3ms/step
# Epoch 27/50
# 381/381 - 1s - loss: 0.0550 - val_loss: 0.0544 - 1s/epoch - 3ms/step
# Epoch 28/50
# 381/381 - 1s - loss: 0.0550 - val_loss: 0.0544 - 1s/epoch - 3ms/step
# Epoch 29/50
# 381/381 - 1s - loss: 0.0549 - val_loss: 0.0543 - 1s/epoch - 3ms/step
# Epoch 30/50
# 381/381 - 1s - loss: 0.0548 - val_loss: 0.0542 - 1s/epoch - 3ms/step
# Epoch 31/50
# 381/381 - 1s - loss: 0.0548 - val_loss: 0.0541 - 1s/epoch - 3ms/step
# Epoch 32/50
# 381/381 - 1s - loss: 0.0547 - val_loss: 0.0540 - 1s/epoch - 3ms/step
# Epoch 33/50
# 381/381 - 1s - loss: 0.0547 - val_loss: 0.0539 - 1s/epoch - 3ms/step
# Epoch 34/50
# 381/381 - 1s - loss: 0.0546 - val_loss: 0.0539 - 1s/epoch - 3ms/step
# Epoch 35/50
# 381/381 - 1s - loss: 0.0546 - val_loss: 0.0539 - 1s/epoch - 3ms/step
# Epoch 36/50
# 381/381 - 1s - loss: 0.0546 - val_loss: 0.0538 - 1s/epoch - 3ms/step
# Epoch 37/50
# 381/381 - 1s - loss: 0.0545 - val_loss: 0.0538 - 1s/epoch - 3ms/step
# Epoch 38/50
# 381/381 - 1s - loss: 0.0545 - val_loss: 0.0538 - 1s/epoch - 3ms/step
# Epoch 39/50
# 381/381 - 1s - loss: 0.0545 - val_loss: 0.0537 - 969ms/epoch - 3ms/step
# Epoch 40/50
# 381/381 - 1s - loss: 0.0544 - val_loss: 0.0537 - 1s/epoch - 3ms/step
# Epoch 41/50
# 381/381 - 1s - loss: 0.0544 - val_loss: 0.0537 - 1s/epoch - 3ms/step
# Epoch 42/50
# 381/381 - 1s - loss: 0.0544 - val_loss: 0.0537 - 1s/epoch - 3ms/step
# Epoch 43/50
# 381/381 - 1s - loss: 0.0544 - val_loss: 0.0536 - 1s/epoch - 3ms/step
# Epoch 44/50
# 381/381 - 1s - loss: 0.0544 - val_loss: 0.0536 - 1s/epoch - 3ms/step
# Epoch 45/50
# 381/381 - 1s - loss: 0.0544 - val_loss: 0.0536 - 1s/epoch - 3ms/step
# Epoch 46/50
# 381/381 - 1s - loss: 0.0544 - val_loss: 0.0536 - 1s/epoch - 3ms/step
# Epoch 47/50
# 381/381 - 1s - loss: 0.0543 - val_loss: 0.0536 - 1s/epoch - 3ms/step
# Epoch 48/50
# 381/381 - 1s - loss: 0.0543 - val_loss: 0.0537 - 1s/epoch - 3ms/step
# Epoch 49/50
# 381/381 - 1s - loss: 0.0543 - val_loss: 0.0536 - 1s/epoch - 3ms/step
# Epoch 50/50
# 381/381 - 1s - loss: 0.0543 - val_loss: 0.0536 - 1s/epoch - 3ms/step

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='Validation')
plt.legend()
plt.show()

# %%
...
#NEW    make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.7f' % rmse)
# Out:
# Test RMSE: 3.4976751

# %%
from sklearn import metrics
from scipy import stats
print('MSE: ', metrics.mean_squared_error(inv_y, inv_yhat))
print('MAE: ', metrics.mean_absolute_error(inv_y, inv_yhat))
print('R2: ', metrics.r2_score(inv_y, inv_yhat))
print('Correlation: ', stats.pearsonr(inv_y, inv_yhat)[0])
print('RMSLE: ',metrics.mean_squared_log_error(np.absolute(inv_y), np.absolute( inv_yhat)))
print('MAPE: ',metrics.mean_absolute_percentage_error(inv_y, inv_yhat))
# Out:
# MSE:  12.233731
# MAE:  2.6208873
# R2:  0.8648591496229997
# Correlation:  0.9309758465547201
# RMSLE:  0.00015310498
# MAPE:  0.009263203

# %%
plt.figure(figsize=(12,5))
plt.xlabel('time')
plt.ylabel('Temperature in Kelvin')
plt.title('Multivariate LSTM ')
plt.style.use('seaborn-darkgrid')


plt.plot(inv_y,color='g', linewidth=1, alpha=0.9, label='Truth')
plt.plot(inv_yhat,color='r', linewidth=1, alpha=0.9,label='Prediction')
#plt. text(2,60000, 'RMSE =9916.220', style='italic',bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})
plt.legend(fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.xlabel('time')
plt.ylabel('Temperature in Kelvin')
plt.title('Multivariate LSTM ')
plt.style.use('seaborn-darkgrid')


plt.plot(inv_y[9000:9120],color='b', linewidth=1, alpha=0.9, label='Truth')
plt.plot(inv_yhat[9001:9121],color='r', linewidth=1, alpha=0.9,label='Prediction')
#plt. text(2,60000, 'RMSE =9916.220', style='italic',bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})
plt.legend(fontsize=12)
plt.show()
